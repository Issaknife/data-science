# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("african_crises.csv")
df = df.set_index('year')
exch_df = df[['country','cc3','exch_usd']]
grouped_df = exch_df.groupby('country')

#List of countries
countries_list = grouped_df['country'].unique()

# %% [markdown]
# Now we're going to plot the USD exchange rate for each country in our list.

# %%
for country in countries_list:
    for e in country:
        grouped_df.get_group(e).plot()

# %%
grouped_df.describe()
# Out:
#                          exch_usd                                        \
#                             count        mean         std           min
# country
# Algeria                      85.0   20.177565   29.413576  5.076100e-02
# Angola                       77.0   15.099671   32.397133  1.250000e-08
# Central African Republic     58.0  367.686066  147.720341  2.009999e+02
# Egypt                       155.0    1.006045    1.725812  1.906000e-01
# Ivory Coast                  63.0  153.320635  185.911988  0.000000e+00
# Kenya                        67.0   30.713180   30.573997  4.958200e+00
# Mauritius                    68.0   13.759661   10.171874  3.308500e+00
# Morocco                      75.0    5.865309    2.921509  5.000000e-01
# Nigeria                      60.0   38.951022   59.077484  0.000000e+00
# South Africa                114.0    1.719339    2.680906  1.892500e-01
# Tunisia                      75.0   50.692807  110.491221  3.865000e-01
# ...
